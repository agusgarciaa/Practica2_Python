# %%
# Dada la siguiente playlist con canciones y sus duraciones en formato "m:ss":
# Calcule la duración total de la playlist en formato Xm Ys, y encuentre la
# canción más larga y la más corta.
# Nota: Deberá convertir las duraciones de string a valores
# numéricos para poder operar con ellas.
# Salida esperada:
# Duración total: 46m 53s
# Canción más larga: "Stairway to Heaven" (8:02)
# Canción más corta: "Imagine" (3:07)
import sys
sys.path.append("../src")

from funciones import total_playtime

playlist = [
    {"title": "Bohemian Rhapsody", "duration": "5:55"},
    {"title": "Hotel California", "duration": "6:30"},
    {"title": "Stairway to Heaven", "duration": "8:02"},
    {"title": "Imagine", "duration": "3:07"},
    {"title": "Smells Like Teen Spirit", "duration": "5:01"},
    {"title": "Billie Jean", "duration": "4:54"},
    {"title": "Hey Jude", "duration": "7:11"},
    {"title": "Like a Rolling Stone", "duration": "6:13"},
]

playtime = total_playtime(playlist)
minutes = playtime // 60
seconds = playtime % 60
print(f"{minutes} : {seconds}")
# Out:
# ---------------------------------------
# NameErrorTraceback (most recent call last)
# Cell In[1], line 26
#      22     {"title": "Hey Jude", "duration": "7:11"},
#      23     {"title": "Like a Rolling Stone", "duration": "6:13"},
#      24 ]
#      25
# ---> 26 playtime = total_playtime(playlist)
#      27 minutes = playtime // 60
#      28 seconds = playtime % 60
#      29 print(f"{minutes} : {seconds}")
#
# File ~\practica2-python\notebooks\../src\funciones.py:47, in total_playtime(playlist)
#      45 for song in playlist:
#      46     time = song["duration"]
# ---> 47     total_seconds = to_seconds(time)
#      48     total += total_seconds
#      49 return total
#
# File ~\practica2-python\notebooks\../src\funciones.py:36, in to_seconds(duration)
#      35 def to_seconds(duration):
# ---> 36     mins, secs = time.split(":")
#      37     mins = int(mins)
#      38     secs = int(secs)
#
# NameError: name 'time' is not defined
