# %%
# Copiado para tenerlo momentaneamente.
# Estadísticas de un texto
# Dado el siguiente texto almacenado en una variable, calcule e imprima:
# La cantidad total de líneas.
# La cantidad total de palabras.
# El promedio de palabras por línea.
# Todas las líneas cuya cantidad de palabras esté por encima del promedio.
# •
# •
# •
# •
# •
# •
# •
# •
# Nota: Este texto es "El Zen de Python", una colección de principios
# que guían el diseño del lenguaje. Puede verlo ejecutando import this
# en Python.
# Salida esperada:
# Total de líneas: 19
# Total de palabras: 137
# Promedio de palabras por línea: 7.21
# Líneas por encima del promedio (7.21 palabras):
# - "Special cases aren't special enough to break the rules." (9 palabras) - "In the face of ambiguity, refuse the temptation to guess." (10 palabr - "There should be one-- and preferably only one --obvious way to do it. - "Although that way may not be obvious at first unless you're Dutch." ( - "Although never is often better than *right* now." (8 palabras)
# - "If the implementation is hard to explain, it's a bad idea." (11 palab - "If the implementation is easy to explain, it may be a good idea." (13 - "Namespaces are one honking great idea -- l

import sys
sys.path.append("../src")

from funciones import count_lines
from funciones import count_words
from funciones import average_words
from funciones import above_average

text = """Beautiful is better than ugly.
Explicit is better than implicit.
Simple is better than complex.
Complex is better than complicated.
Flat is better than nested.
Sparse is better than dense.
Readability counts.
Special cases aren't special enough to break the rules.
Although practicality beats purity.
Errors should never pass silently.
Unless explicitly silenced.
In the face of ambiguity, refuse the temptation to guess.
There should be one-- and preferably only one --obvious way to do it.
Although that way may not be obvious at first unless you're Dutch.
Now is better than never.
Although never is often better than *right* now.
If the implementation is hard to explain, it's a bad idea.
If the implementation is easy to explain, it may be a good idea.
Namespaces are one honking great idea -- let's do more of those!"""

print(count_lines(text))
print(count_words(text))
average = average_words(text)
print(round(average, 2))
lines = above_average(text)
for line in lines:
    print(line)
# Out:
# 19
# 137
# 7.21
# Special cases aren't special enough to break the rules.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!
